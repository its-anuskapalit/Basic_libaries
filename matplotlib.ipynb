# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
 x_data = np.random.rand(50)*100 
 y_data = np.random.rand(50) *100

# %%
plt.scatter(x_data,y_data)
plt.show()

# %%
print(x_data)
print(y_data)
# Out:
# [49.65858926 20.65197888 13.88106261 36.58623499  3.97561013 91.4506988
#  64.3545969  73.77228074 18.48010491 93.11997987 12.35815416 95.7734346
#  23.62945742 53.17390878 99.44965474 72.43210168  7.27717621 48.85984359
#   1.828497   54.77767354 94.10822955 91.39092147 70.83673108 70.61490934
#  20.65170129 27.13367254 70.13921945 13.30210137 80.76890942  0.88351555
#  97.68414513 29.22997559 78.33673605 21.11855545 64.06522927 84.93346805
#  41.47549752 83.12326551 44.34375028  4.3569392  61.09836526 45.70741127
#  55.91541851 87.63476384 92.76939029 24.30913145 17.47172809 85.30720277
#  54.80796303 34.13635218]
# [46.92693907 65.92273511 84.05454349 18.22660915 78.62814309 93.14671788
#  78.64619923  4.89712411 10.43511176 72.12029466 50.41210418 19.09244741
#  53.66238283 70.26068638 81.61572085 22.42459369 53.71556039 35.35551018
#  88.40969548 44.70637127 99.72490535 10.72128015 47.82047556 45.50846072
# ...

# %%
plt.scatter(x_data,y_data,c="red",marker="+",s=150)
plt.show()

# %%
year= [2006 + x for x in range(16)]
weight=[80,83,84,12,15,89,10,36,99,74,32,18,89,74,59,99]
print(year)
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
plt.plot(year,weight,lw=8,linestyle="--")
plt.show()
plt.scatter(year,weight)
plt.show()

# %%
x=["c++","c","python","java","go"]
y=[20,56,65,85,45]
plt.bar(x,y)
plt.show()

# %%
plt.bar(x,y,color="r",align="edge",width=0.5,edgecolor="green",lw=6)
plt.show()

# %%
ages=np.random.normal(20,7.5,100)
print(ages)
# Out:
# [22.5218424  16.69445918  5.26967947 27.66393572 14.42843767 16.31975467
#  21.03650636 28.18061301 26.45638007  9.95486954 18.03434776 29.59150098
#  22.0972301  13.50931669 26.06787295 25.93565794 17.3846806  50.3210162
#  27.89990475  9.82462092 17.22789459 23.40480896 24.45906995 23.61608138
#  33.90563025 15.88850641 25.2740443  15.38865708 12.3270274  10.20341109
#  23.18188356 25.07504681  6.84258371 17.0766819   6.36178926  5.95994619
#  21.07864269 14.91905491 13.75884126 26.81349979 22.0035881  14.05060154
#  16.97540072 25.80325824 20.49422027 10.17678079 22.51572988 33.49443886
#  17.41550079 16.01142214 17.14382775 25.30257414 19.708319   10.23997175
#  13.16868364 21.53759259 20.25814014  5.31454132 15.76455409 27.26863512
#  20.1906544  22.37077354 19.30463135 14.96387575  6.78902365 27.5962919
#  23.48811016 24.52409616 34.82703239 16.39603072 14.3034313  33.38355386
#  28.59155211 23.54669819 12.02058767 20.84070401 16.69782901 30.7534828
# ...

# %%
plt.hist(ages,bins=20)
plt.show()

# %%
langs=["c++","c","python","java","go"]
votes=[20,56,65,85,45]
exp=[0,0,0,0, 0.2]

# %%
plt.pie(votes,labels=langs,explode=exp,autopct="%.2f%%",pctdistance=1.6)
plt.show()

# %%
heights=np.random.normal(172,8,300)
plt.boxplot(heights)
plt.show()

# %%
years=[2004,2005,2006,2007,
      2008,2009,2010,2011]
income=[5500,5600,6200,6100,
       7100,7200,7600,8500]
income_tickets=list(range(5500,9000,2))
plt.plot(years,income)
plt.title("INCOME FOR JOHN")
plt.xlabel("income")
plt.ylabel("years")
plt.show()

# %%
a=[100,102,101,103]
b=[70,95,105,85]
c1=[78,96,102,163]

# %%
plt.plot(a,label="Apple")
plt.plot(b,label="Tesla")
plt.plot(c1,label="Micosoft")
plt.legend()
plt.show()

# %%
x1,y1=np.random.rand(100),np.random.rand(100)
x2,y2=np.random.rand(100),np.random.rand(100)

# %%
plt.figure(1)
plt.scatter(x1,y1)
plt.figure(2)
plt.scatter(x2,y2)
plt.show()

# %%
x= np.arange(1,101)
fig,axs=plt.subplots(2,2)
axs[0,0].plot(x,np.sin(x))
axs[0,0].set_title("Sine Wave")

axs[0,1].plot(x,np.cos(x))
axs[0,1].set_title("Cosine Wave")
print("\n")
axs[1,0].plot(x,np.random.rand(100))
axs[1,0].set_title("Random")


axs[1,1].plot(x,np.log(x))
axs[1,1].set_title("Log Wave")
fig.suptitle("Four Plots")
plt.show()

# %%
ax=plt.axes(projection="3d")
x=np.random.rand(100)
y=np.random.rand(100)
z=np.random.rand(100)
ax.scatter(x,y,z)
ax.set_title("3D  Plot")
plt.show()

# %%
ax=plt.axes(projection="3d")
x=np.arange(0,50,0.1)
y=np.sin(x)
z=np.cos(x)
ax.plot(x,y,z)
ax.set_title("3D  Plot")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = np.sin(X) * np.cos(Y)
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_title("3D Plot")
plt.show()
